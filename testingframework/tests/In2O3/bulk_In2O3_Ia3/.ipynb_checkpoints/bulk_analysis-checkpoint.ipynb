# %% [markdown]
# # Demonstration of Interatomic Potential Testing Framework
#
# **James Kermode**
# <br>
# March 2021
#
# Data and code available from https://github.com/libAtoms/testing-framework
#
# Running Model:
# ```bash
#
# ```

# %%
import itertools
import json
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nglview
import matplotlib.pyplot as plt
import seaborn as sns

from ase.io import read

sns.set_context('talk')

os.chdir(os.path.expanduser('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/testing-framework/example_models/In2O3/run_dir'))
! [[ ! -d ../tests ]] && ln -s ~/tests/Si ../tests
# Out:
# ln: failed to create symbolic link '../tests': File exists

# %%
import seaborn as sns

# %% [markdown]
# ## Energy-Volume curves
#
# We can read in the existing data:
#
# In2O3-model-DFT_QE-test-bulk_In2O3_Ia3-properties

# %%
def read_data(model_names, sym='Ia3', raise_error=True):
    data = {}
    for model_name in model_names:
        json_file = f"In2O3-model-{model_name}-test-bulk_In2O3_{sym}-properties.json"
        #model_name = os.path.basename(json_file).split('-')[2]
        
        if not os.path.exists(json_file):
            print(f'Json file for model and test doesnt exist: {json_file}')
            if raise_error:
                raise FileNotFoundError(f'Json file doesnt exist: {fname}')
            else:
                # Move on to next model 
                continue
                
        data[model_name] = json.load(open(json_file))
    return data

# %% [markdown]
# Now we define some simple functions to plot energy volume curves for the reference DFT and GAP models. Here we fit a quartic polynomial to the data.

# %%
#data

# %%
def polyplot(ax, V, E, color, label):
    y = E #- (-1128.25) #- E.min()
    p = np.polyfit(np.array(V, dtype=float), np.array(y,dtype=float), 4)
    v = np.linspace(V.min(), V.max(), 100)
    e = np.polyval(p, v)
    #print(V,E)
    ax.plot(V, y, color+'.', label=label+' data')
    ax.plot(v, e, color+'-', label=label+' fit')

def plot_e_vs_v(all_data, ref_model_name, colors=None, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(12,8))
    #polyplot(ax, ref_E_vs_V[:,0], ref_E_vs_V[:,1], 'k', ref_model_name)
    
    if colors is None:
        colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
        
    for i, model_name in enumerate(all_data): 
        color =  colors[i%len(colors)]
        if model_name == ref_model_name:
            color='k'
        data = all_data[model_name]
        E_vs_V = np.array(data['E_vs_V'], dtype=object)
        V = E_vs_V[:, 0].astype(float)
        E = E_vs_V[:, 1].astype(float)
        polyplot(ax, V, 
                 E ,#- E.min(), 
                 color, model_name)        
    

    ax.set_xlabel(r'Volume / $\mathrm{\AA}^3$')
    ax.set_ylabel('Energy / eV')
    ax.legend()
    
    return ax

# %%
colors = ['C0', 'C1', 'C2', 'C3', 'C4']
for i, model_name in enumerate(data): 
    print(model_name, colors[i%len(colors)])
# Out:
# GAP_it1_50s C0
# GAP_itB_1_a C1
# GAP_itB_1_b C2
# GAP_itB_1_b_2 C3
# GAP_itB_1_c_2 C4
# GAP_itB_1_a_2 C0
# GAP_itB_1_c C1

# %% [markdown]
# # Volume density analysis

# %%
ats = read('/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It3_3/Training/Data_b_GAP_train.xyz', ':')
vols = []
for at in ats:
    if at.info['type'].lower() == 'bulk':
        vols.append(at.get_volume()/at.get_global_number_of_atoms())
        
plt.hist(vols, bins=100);

# %% [markdown]
# # Running analysis

# %%
def get_all_models():
    d = '../models/'
    models = [os.path.join(o) for o in os.listdir(d) 
              if os.path.isdir(os.path.join(d,o))]
    
    return models
np.array(get_all_models()).flatten()
# Out:
# array(['GAP_it1_50s', 'GAP_itB_1_a', 'GAP_itB_2_b_1', 'DFT_QE',
#        'GAP_itB_1_b', 'GAP_itB_2_b_2', 'GAP_itB_1_b_2', 'GAP_itB_1_c_2',
#        'GAP_itB_1_a_2', 'GAP_itB_1_c'], dtype='<U13')

# %%
syms = ['Ia3', 'R3c','Pbca', 'Pbcn']
models = [
    'DFT_QE', 
    'GAP_it1_50s', # 'GAP_itB_1_c_2',
    #'GAP_itB_1_a','GAP_itB_1_b', 'GAP_itB_1_c','GAP_itB_1_a_2'
    #'GAP_itB_1_b_2', 'GAP_itB_2_b_1', 'GAP_itB_1_b'
    'GAP_itB_1_b_2', #'GAP_itB_1_c_2',
#     'GAP_itB_1_c', 'GAP_itB_1_c_2',
#     'GAP_itB_1_b_2', 'GAP_itB_2_b_2',
    #'GAP_itB_1_b_2', 
    #'GAP_itB_2_b_3', 'GAP_itB_3_b_3', 'GAP_itB_4_b_3',
    'GAP_itB_2_b_2', 'GAP_itB_3_b_2', 'GAP_itB_4_b_2',






]

#models = get_all_models()

for sym in syms:
    fig, axs = plt.subplots(2,1, figsize=(15,15), gridspec_kw={'height_ratios':[3,1]}, sharex=True)
    
    print(f'Trying Symetry: {sym}')
    data = read_data(models, sym=sym, raise_error=False) 
    models_sym = [i for i in models if np.isin(i, list(data.keys())) ]
    ref_model_name = 'DFT_QE'
    print(ref_model_name)
    axs[0] = plot_e_vs_v(data, ref_model_name,ax=axs[0])
    axs[0].set(title=f'Bulk Investigation: {sym}', xlabel=None)
    axs[1].hist(vols, bins=80)
    axs[1].set(ylabel='count', xlabel='Volume/atom ($\AA ^3$)')
    plt.subplots_adjust(wspace=0, hspace=0)
    #axs[0].legend()
    plt.savefig(f'{sym}.pdf')
    #sns.scatterplot(x='volume', y='energies', hue='model', data=df, ax=axs[0],markers=None)   
    axs[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))


    plt.show()


    break
# Out:
# Trying Symetry: Ia3
# Json file for model and test doesnt exist: In2O3-model-GAP_itB_4_b_2-test-bulk_In2O3_Ia3-properties.json
# DFT_QE

# %%
# !pwd
# Out:
# /home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/testing-framework/example_models/In2O3/run_dir

# %%
np.min(np.array(data['DFT_QE']['E_vs_V'], dtype=object)[:,0]) - np.min(np.array(data['GAP_it1_50s']['E_vs_V'], dtype=object)[:,0] )
# Out:
# -0.0631698790727846

# %% [markdown]
# # Checking wether plots actually correspond to info in .xyz files
#
# Here I just double check that the information stored in the json files corresponds to the info in the .xyz calculations. They do!
#
# This mighte be a stupid way of doing things

# %%
i = 9
at1 = read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/'
           'testing-framework/example_models/In2O3/run_dir/run_In2O3-model-G'
           f'AP_itB_1_b-test-bulk_In2O3_Ia3/In2O3-model-GAP_itB_1_b-test-bulk_In2O3_Ia3-E_vs_V_-0{i}-relaxed.xyz')
at2 = read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/'
           'testing-framework/example_models/In2O3/run_dir/run_In2O3-model-D'
           f'FT_QE-test-bulk_In2O3_Ia3/In2O3-model-DFT_QE-test-bulk_In2O3_Ia3-E_vs_V_-0{i}-relaxed.xyz')

# %%
for i in range(1,9):
    at1 = read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/'
               'testing-framework/example_models/In2O3/run_dir/run_In2O3-model-G'
               f'AP_itB_1_b-test-bulk_In2O3_Ia3/In2O3-model-GAP_itB_1_b-test-bulk_In2O3_Ia3-E_vs_V_-0{i}-relaxed.xyz')
    at2 = read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/'
               'testing-framework/example_models/In2O3/run_dir/run_In2O3-model-D'
               f'FT_QE-test-bulk_In2O3_Ia3/In2O3-model-DFT_QE-test-bulk_In2O3_Ia3-E_vs_V_-0{i}-relaxed.xyz')
    print('GAP itB 1 b : {} A^3, {} eV'.format(at1.get_volume()/at1.get_global_number_of_atoms(), 
                                               at1.get_potential_energy()/at1.get_global_number_of_atoms()))
    print('QE DFT      : {} A^3, {} eV'.format(at2.get_volume()/at2.get_global_number_of_atoms(), 
                                               at2.get_potential_energy()/at1.get_global_number_of_atoms() + 1128.25))
    print('-'*60)
# Out:
# GAP itB 1 b : 14.004497758975196 A^3, -1128.7748953744758 eV
# QE DFT      : 13.230714955022904 A^3, -1128.7684457793243 eV
# ------------------------------------------------------------
# GAP itB 1 b : 14.346070875047754 A^3, -1128.7545912676721 eV
# QE DFT      : 12.891465853611958 A^3, -1128.7546005546853 eV
# ------------------------------------------------------------
# GAP itB 1 b : 14.687643991120893 A^3, -1128.7242378593514 eV
# QE DFT      : 12.552216752201145 A^3, -1128.72994162048 eV
# ------------------------------------------------------------
# GAP itB 1 b : 15.029217107193137 A^3, -1128.684675065706 eV
# QE DFT      : 12.212967650790342 A^3, -1128.6936161378565 eV
# ------------------------------------------------------------
# GAP itB 1 b : 15.370790223265402 A^3, -1128.6495663724186 eV
# QE DFT      : 11.873718549379515 A^3, -1128.6436174065532 eV
# ------------------------------------------------------------
# GAP itB 1 b : 15.712363339338136 A^3, -1128.6137556851413 eV
# QE DFT      : 11.534469447968597 A^3, -1128.5772859727788 eV
# ------------------------------------------------------------
# GAP itB 1 b : 16.0539364554108 A^3, -1128.5747415745004 eV
# QE DFT      : 11.195220346557779 A^3, -1128.492903641591 eV
# ------------------------------------------------------------
# GAP itB 1 b : 16.39550957148321 A^3, -1128.5339998105221 eV
# QE DFT      : 10.85597124514686 A^3, -1128.3871102898186 eV
# ------------------------------------------------------------

# %%
vols
# Out:
# [10.85597124514686,
#  10.177473042325335,
#  12.891465853611958,
#  12.212967650790342,
#  11.534469447968597]

# %%
df = pd.DataFrame({
    'ItB_1_b': [11.60606197758448,
     10.24064292139812,
     12.288771505677735,
     10.923352449491286,
     12.971481033770953],
    'ItB_1_a': [11.534469447968618,
 12.21296765079032,
 10.177473042325264,
 12.891465853611994,
 10.855971245146947],
    'ItB_1_c': [10.85597124514686,
 10.177473042325335,
 12.891465853611958,
 12.212967650790342,
 11.534469447968597],
    
})

# %%
df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(data=df, boxprops=dict(alpha=.6))
ax = sns.swarmplot(data=df, color='.25')

# %% [markdown]
# # Checking what is in training it_2_b_2
#
# Why does training on mehtod b make it worse. Lets have a look at the configurations.

# %%
pd.DataFrame()

# %%
import os
import ase.io
dirs = [
    '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It1_2/Training/Data_b_GAP/GAP_ORG',
     '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It1_2/Training/Data_b_GAP/',
     '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It2_3/Training/Data_b_GAP/GAP_ORG',
     '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It2_3/Training/Data_b_GAP/',
     '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It3_3/Training/Data_b_GAP/GAP_ORG',
     '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It3_3/Training/Data_b_GAP',
    '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP/GAP_ORG',
    '/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP',
]
names = ['GAP evals GAP_itB_0_b_3', 'QE evals GAP_itB_0_b_3','GAP evals GAP_itB_1_b_3', 'QE evals GAP_itB_1_b_3', 'GAP evals GAP_itB_2_b_3', 'QE evals GAP_itB_2_b_3', 'GAP evals GAP_itB_3_b_3', 'QE evals GAP_itB_3_b_3']
df=pd.DataFrame()
for i, direct in  enumerate(dirs):
    print(f'Dir: {direct}')
    atoms=[]
    energies=[]
    volumes=[]
    
    
    for file in os.listdir(direct):
        if file.endswith(".xyz"):
            print(f'  Analysing: {file}')
            ats = ase.io.read(os.path.join(direct, file))
            volumes.append(ats.get_volume()/ats.get_global_number_of_atoms())
            energies.append(ats.get_potential_energy()/ats.get_global_number_of_atoms())
            
            atoms.append(ats)
    
    dfi=pd.DataFrame({'model': names[i].split(' ')[-1], 'method': names[i].split(' ')[0],'volume': volumes, 'energies':energies})
    df= df.append(dfi)
# Out:
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It1_2/Training/Data_b_GAP/GAP_ORG
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_09-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed.xyz
#   Analysing: In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It1_2/Training/Data_b_GAP/
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_it1_50s-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed_0.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It2_3/Training/Data_b_GAP/GAP_ORG
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed.xyz
#   Analysing: _train.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It2_3/Training/Data_b_GAP/
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_1_b_2-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed_0.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It3_3/Training/Data_b_GAP/GAP_ORG
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_09-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It3_3/Training/Data_b_GAP
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_09-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_2_b_3-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed_0.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP/GAP_ORG
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed.xyz
#   Analysing: In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed.xyz
# Dir: /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-06-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_04-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_10-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_-02-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_08-relaxed_0.xyz
#   Analysing: QE_In2O3-model-GAP_itB_3_b_3-test-bulk_In2O3_Ia3-E_vs_V_02-relaxed_0.xyz

# %%
names[0].split(' ')[0]
# Out:
# 'GAP'

# %%
fig, ax = plt.subplots(figsize=(12,12))
ax.plot([10.17747304, 10.51672214, 10.85597125, 11.19522035, 11.53446945, 11.87371855
, 12.21296765, 12.55221675, 12.89146585, 13.23071496, 13.56996406, 13.90921316
, 14.24846226, 14.58771136, 14.92696046, 15.26620956, 15.60545866, 15.94470777
, 16.28395687, 16.62320597, 16.96245507], [-1128.09899204, -1128.25709086, -1128.38711029, -1128.49290364
, -1128.57728597, -1128.64361741, -1128.69361614, -1128.72994162
, -1128.75460055, -1128.76844578, -1128.77354858, -1128.7708832
, -1128.76116118, -1128.74622801, -1128.72604385, -1128.70191854
, -1128.67410817, -1128.64331535, -1128.61022175, -1128.57586494
, -1128.54034853], 'k--', label='True DFT')

sns.scatterplot(x='volume', y='energies', hue='model', data=df, style='method')
# Out:
# <AxesSubplot:xlabel='volume', ylabel='energies'>

# %%
(len(ase.io.read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/testing-framework/example_models/In2O3/models/GAP_itB_3_b_3/gap_fit/train.xyz', ':')),
len(ase.io.read('/home/lls34/GitHub/01_PhD/PhD_Code/submodules/testing-framework/testing-framework/example_models/In2O3/models/GAP_itB_2_b_3/gap_fit/train.xyz', ':')))
# Out:
# (569, 559)

# %% [markdown]
# # Look at training set

# %%
atst = ase.io.read('/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP_train.xyz', '-40:')

# %%
len(atst)
# Out:
# 40

# %%
ase.io.write('/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP_train_only_new.xyz', atst)
# Out:
# /home/lls34/miniconda3/envs/phd-code/lib/python3.8/site-packages/ase/io/extxyz.py:997: UserWarning: write_xyz() overwriting array "forces" present in atoms.arrays with stored results from calculator
#   warnings.warn('write_xyz() overwriting array "{0}" present '

# %%
from gapalysis.data import Trajectory

t = Trajectory.from_xyz('/data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/Data_b_GAP_train_only_new.xyz')
# Out:
# [data      ] Configuration: 1/40
# [data      ] Added per atom force norm
# [data      ] !! Using HACK!! reading single atom ens from /data/lls34/Data/In2O3/In2O3_LS_1/04_QE2/02_Ameliorate_GAP/02_Itterative/03_Bulk/Volume_Curves/It4_3/Training/e0.h5
# [data      ] Added Per Atom Properites

# %%
t.df_energies[['pe']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'pe'}>]], dtype=object)

# %%
t.df_forces[['f']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'f'}>]], dtype=object)

# %% [markdown]
# ## Bulk Properties
# ```
# ![image.png](attachment:f1dcf3a5-b8b1-4742-b92f-8e4db63ff408.png)
# ```
# As well as the energy volume curve, the bulk test computes a number of other bulk properties, which we can tabulate:

# %%
df = pd.DataFrame(data)
df.drop('E_vs_V')
# Out:
#     GAP_it1_50s
# c11  167.440418
# c12   70.843958
# c13   40.789197
# c22  184.776555
# c23   60.981165
# c33  140.147565
# c44   51.734007
# c55   61.211408
# c66   40.346927

# %% [markdown]
# ## Adding a new model
#
# Let's define a model for the screened Tersoff potential as implemented in `atomistica`. This is as simple as creating a `model.py` file in the `models/TersoffScr` directory.

# %%
![[ ! -d ../models/TersoffScr ]] && mkdir ../models/TersoffScr

with open("../models/TersoffScr/model.py", "w") as f:
    f.write("""
from atomistica import TersoffScr

calculator = TersoffScr()
name = 'TersoffScr'
no_checkpoint = True
""")

# %% [markdown]
# ## Rerunning a single test with the new model
#
# We can rerun an individual test with the `run-model-test.py` script: this takes the name of the model and of the test as arugments, and usually captures the output to a logfile. The `-l` option gives a label for the set of calculations; here we use `"Si"` to match with what was done for the GAP and DFT tests.

# %%
 # !python ../../../scripts/run-model-test.py -l Si TersoffScr bulk_Si_diamond
# Out:
# share_dir /home/jovyan/scripts/../share

# %% [markdown]
# If we try to run the test again, it notices the `.json` file is present and avoids rerunning - this time we add the `-N` option to turn off capturing of stdout so we can see it directly in the notebook:

# %%
 # !python ../../../scripts/run-model-test.py -N -l Si TersoffScr bulk_Si_diamond
# Out:
# share_dir /home/jovyan/scripts/../share
# ../Si-model-TersoffScr-test-bulk_Si_diamond-properties.json already exists and is not empty, not rerunning test

# %% [markdown]
# ## Repeating the postprocessing analysis
#
# Now we can go back and add the `TersoffScr` results to our energy-volume plot and data table:

# %%
data = read_data(['CASTEP_ASE', 'GAP', 'TersoffScr'])
plot_e_vs_v(data, ref_model_name)

display(pd.DataFrame(data).drop('E_vs_V'))
# Out:
#     CASTEP_ASE         GAP  TersoffScr
# B    88.596697   88.810217   96.897975
# c12   56.25009   57.523404   74.571981
# c11  153.28991  151.383845  141.549961
# c44   72.17693   67.863739    68.82712
# a0    5.461022    5.460805         NaN

# %% [markdown]
# The `NaN` for **a0** indicates missing data, not a failure with the test: the `bulk_Si_diamond` test no longer stores the lattice constant, but instead saves the full relaxed cell, which we can read in and visualise:

# %%
atoms = read('Si-model-TersoffScr-test-bulk_Si_diamond-relaxed.xyz')
v = nglview.show_ase(atoms * 3, cell=True)
v.add_unitcell()
v
# Out:
# NGLWidget()

# %% [markdown]
# We can update our data table accordingly:

# %%
data['TersoffScr']['a0'] = atoms.cell[0, 0] * 2.0
display(pd.DataFrame(data).drop('E_vs_V'))
# Out:
#     CASTEP_ASE         GAP  TersoffScr
# B    88.596697   88.810217   96.897975
# c12   56.25009   57.523404   74.571981
# c11  153.28991  151.383845  141.549961
# c44   72.17693   67.863739    68.82712
# a0    5.461022    5.460805    5.436147

# %% [markdown]
# ## Running all model/test pairs
#
# To fill in results for missing model/test pairs, we could use the `run-all.py` script. By default this would run all pairs, but here we restrict to our new model to fill in the remainder of the tests with the `TersoffScr` potential.
#
# This takes a few minutes to complete.

# %%
 # !python ../../../scripts/run-all.py -s Si --models TersoffScr
# Out:
# Models asked for:  ['TersoffScr']
# Models path:  /home/jovyan/example_models/Si/run_dir/../models
# Models found:  ['/home/jovyan/example_models/Si/run_dir/../models/TersoffScr/model.py']
# Models: ['/home/jovyan/example_models/Si/run_dir/../models/TersoffScr']
# Tests: [('/home/jovyan/scripts/../tests/Si/qha_diamond', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_simple_hexagonal', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface-decohesion-111-unrelaxed', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_bc8', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_hcp', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface-decohesion-110-unrelaxed', 'Si'), ('/home/jovyan/scripts/../tests/Si/phonon_bulks', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_fcc', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_hexagonal_diamond', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface-decohesion-100-unrelaxed', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_hcp_sf', 'Si'), ('/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_vacancy', 'Si'), ('/home/jovyan/scripts/../tests/Si/RSS', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface-energy-110-relaxed', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface_Si_diamond_110', 'Si'), ('/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_tetr', 'Si'), ('/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_dumb', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_diamond', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface_Si_diamond_100', 'Si'), ('/home/jovyan/scripts/../tests/Si/surface_Si_diamond_111', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_beta-Sn', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_st12', 'Si'), ('/home/jovyan/scripts/../tests/Si/bulk_Si_bcc', 'Si'), ('/home/jovyan/scripts/../tests/Si/gap_6_rss_like_open_ended_minima_rerelax_sd2', 'Si'), ('/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_hex', 'Si')]
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/qha_diamond', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_simple_hexagonal', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface-decohesion-111-unrelaxed', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_bc8', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_hcp', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface-decohesion-110-unrelaxed', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/phonon_bulks', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_fcc', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_hexagonal_diamond', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface-decohesion-100-unrelaxed', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_hcp_sf', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_vacancy', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/RSS', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface-energy-110-relaxed', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface_Si_diamond_110', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_tetr', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_dumb', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_diamond', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ../Si-model-TersoffScr-test-bulk_Si_diamond-properties.json already exists and is not empty, not rerunning test
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface_Si_diamond_100', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/surface_Si_diamond_111', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_beta-Sn', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_st12', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/bulk_Si_bcc', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/gap_6_rss_like_open_ended_minima_rerelax_sd2', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
# ['python', '/home/jovyan/scripts/run-model-test.py', '/home/jovyan/example_models/Si/run_dir/../models/TersoffScr', '/home/jovyan/scripts/../tests/Si/point_defect_Si_diamond_interstitial_hex', '--system_label', 'Si']
# share_dir /home/jovyan/scripts/../share
